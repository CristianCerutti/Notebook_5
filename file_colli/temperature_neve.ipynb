# %%
import numpy as np
import csv

# %%
#COLLE AGNELLO
#NEVE: data, altezza neve, neve fresca
#TEMPERATURA: data, minima, media, massima

neve_colle_agnello = {}
data_neve_colle = []
neve_suolo_colle = []
neve_fresca_colle = []

temperature_colle_agnello = {}
data_colle = []
ora_minimo_colle = []
Tmin_colle = []
classe_minimo_colle = []
Tmed_colle = []
classe_media_colle = []
ora_massimo_colle = []
Tmax_colle = []
classe_massimo_colle = []
i = 0

file = open("richiesta_dati_gg_80749_parte1.csv")
file1 = open("richiesta_dati_gg_80749_parte4.csv")

while(i<10):
        next(file)
        i+=1
i=0        
while(i<10):
        next(file1)
        i+=1
        
file_reader = csv.reader(file,delimiter=",")
file_reader1 = csv.reader(file1,delimiter=",")

for riga in file_reader:
    if riga[0] == "Elaborato il 2021-12-06 alle ore 21:00 UTC":
        continue
    data_colle.append(riga[0])
    ora_minimo_colle.append(riga[1])
    Tmin_colle.append(riga[2])
    classe_massimo_colle.append(riga[3])
    Tmed_colle.append(riga[4])
    classe_media_colle.append(riga[5])
    ora_massimo_colle.append(riga[6])
    Tmax_colle.append(riga[7])
    classe_massimo_colle.append(riga[8])

data_colle = np.array(data_colle)
ora_minimo_colle = np.array(ora_minimo_colle)
Tmin_colle = np.array(Tmin_colle)
classe_massimo_colle = np.array(classe_massimo_colle)
Tmed_colle = np.array(Tmed_colle)
classe_media_colle = np.array(classe_media_colle)
ora_massimo_colle = np.array(ora_massimo_colle)
Tmax_colle = np.array(Tmax_colle)
classe_massimo_colle = np.array(classe_massimo_colle)



temperature_colle_agnello["data_colle"] = data_colle
temperature_colle_agnello["ora_minimo_colle"] = ora_minimo_colle
temperature_colle_agnello["Tmin_colle"] = Tmin_colle
temperature_colle_agnello["classe_massimo_colle"] = classe_massimo_colle
temperature_colle_agnello["Tmed_colle"] = Tmed_colle
temperature_colle_agnello["classe_media_colle"] = classe_media_colle
temperature_colle_agnello["ora_massimo_colle"] = ora_massimo_colle
temperature_colle_agnello["Tmax_colle"] = Tmax_colle
temperature_colle_agnello["classe_massimo_colle"] = classe_massimo_colle    


for riga in file_reader1:
    if riga[0] == "Elaborato il 2021-12-06 alle ore 21:00 UTC":
        continue
    data_neve_colle.append(riga[0])
    neve_suolo_colle.append(riga[1])
    neve_fresca_colle.append(riga[2])
    
data_neve_colle = np.array(data_neve_colle)    
neve_suolo_colle = np.array(neve_suolo_colle)    
neve_fresca_colle = np.array(neve_fresca_colle)        

neve_colle_agnello["data_neve_colle"] = data_neve_colle
neve_colle_agnello["neve_suolo_colle"] = neve_suolo_colle
neve_colle_agnello["neve_fresca_colle"] = neve_fresca_colle 

#neve_colle_agnello
#temperature_colle_agnello

# %%
#DIGA CHIOTAS
neve_diga = {}
data_neve_diga = []
neve_suolo_diga = []
neve_fresca_diga = []

temperature_diga = {}
data_diga = []
ora_minimo_diga = []
Tmin_diga = []
classe_minimo_diga = []
Tmed_diga = []
classe_media_diga = []
ora_massimo_diga = []
Tmax_diga = []
classe_massimo_diga = []
i = 0

file2 = open("richiesta_dati_gg_80749_parte2.csv")
file3 = open("richiesta_dati_gg_80749_parte3.csv")

while(i<10):
        next(file2)
        i+=1
i=0        
while(i<10):
        next(file3)
        i+=1
        
file_reader2 = csv.reader(file2,delimiter=",")
file_reader3 = csv.reader(file3,delimiter=",")

for riga in file_reader3:
    if riga[0] == "Elaborato il 2021-12-06 alle ore 21:00 UTC":
        continue
    data_diga.append(riga[0])
    ora_minimo_diga.append(riga[1])
    Tmin_diga.append(riga[2])
    classe_massimo_diga.append(riga[3])
    Tmed_diga.append(riga[4])
    classe_media_diga.append(riga[5])
    ora_massimo_diga.append(riga[6])
    Tmax_diga.append(riga[7])
    classe_massimo_diga.append(riga[8])

data_diga = np.array(data_diga)
ora_minimo_diga = np.array(ora_minimo_diga)
Tmin_diga = np.array(Tmin_diga)
classe_massimo_diga = np.array(classe_massimo_diga)
Tmed_diga = np.array(Tmed_diga)
classe_media_diga = np.array(classe_media_diga)
ora_massimo_diga = np.array(ora_massimo_diga)
Tmax_diga = np.array(Tmax_diga)
classe_massimo_diga = np.array(classe_massimo_diga)



temperature_diga["data_diga"] = data_diga
temperature_diga["ora_minimo_diga"] = ora_minimo_diga
temperature_diga["Tmin_diga"] = Tmin_diga
temperature_diga["classe_massimo_diga"] = classe_massimo_diga
temperature_diga["Tmed_diga"] = Tmed_diga
temperature_diga["classe_media_diga"] = classe_media_diga
temperature_diga["ora_massimo_diga"] = ora_massimo_diga
temperature_diga["Tmax_diga"] = Tmax_diga
temperature_diga["classe_massimo_diga"] = classe_massimo_diga    


for riga in file_reader2:
    if riga[0] == "Elaborato il 2021-12-06 alle ore 21:00 UTC":
        continue
    data_neve_diga.append(riga[0])
    neve_suolo_diga.append(riga[1])
    neve_fresca_diga.append(riga[2])
    
data_neve_diga = np.array(data_neve_diga)    
neve_suolo_diga = np.array(neve_suolo_diga)    
neve_fresca_diga = np.array(neve_fresca_diga)        

neve_diga["data_neve_diga"] = data_neve_diga
neve_diga["neve_suolo_diga"] = neve_suolo_diga
neve_diga["neve_fresca_diga"] = neve_fresca_diga

# %%
n_giorni_diga_neve = 0
n_giorni_colle_neve = 0
for elemento in neve_diga["neve_suolo_diga"]:
    if elemento.replace(" ", "") == "":
        continue
    if int(elemento) == 0:
        n_giorni_diga_neve += 1       
print(n_giorni_diga_neve)

for elemento in neve_colle_agnello["neve_suolo_colle"]:
    if elemento.replace(" ", "") == "":
        continue
    if int(elemento) == 0:
        n_giorni_colle_neve += 1       
print(n_giorni_colle_neve)
# Out:
# 723
# 377
